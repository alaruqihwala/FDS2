# %% [markdown]
# # matplotlib homework

# %% [markdown]
# 1. Make a plot of a straight line. Use `linspace()` to create the *x* values and the formula of a straight line, *y = a + b*x*, to create the *y* values (use an *a* and *b* of your choosing). You can pretend x and y are anything you like (x = time, y = international piracy or whatever).

# %%
import numpy as np 
import matplotlib.pyplot as plt # importing the needed libraries

plotx = np.linspace(0, 20, 50) #making a random sequence
a, b = (0, 3.7) #my a and b variables
ploty = a + b * a_plotx #making the formula 
plt.plot(plotx, ploty) # plotting everything

# %% [markdown]
# 2. Make some data that are straight line values from the same straight line relationship as in 1. plus random noise. Plot these data.

# %%
another_x = np.linspace(0, 20, 50)

a, b = 0, 3.7
noise = 0.3
a_ploty = a + b * a_plotx + np.random.randn(len(a_plotx)) # generating random numbers

plt.plot(a_plotx, a_ploty, 'm')

# %% [markdown]
# 3. Plot the straight line from 1. and the data from 2. on the same graph. Make sure to add the standard annotations, including a legend.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(plotx, ploty, 'k--', label = 'linear trend line')
plt.plot(a_plotx, a_ploty, 'om', label = 'data')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Data with a Linear Trend')
plt.legend()

# %% [markdown]
# 4. Tinker around with your plot (colors, symbols, marker sizes, etc.) until you have a plot you would be happy to use in a presentation.

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.plot(plotx, ploty, 'k-', label = 'linear trend line', linewidth = 1)
plt.plot(a_plotx, a_ploty, 'ob', label = 'data', markersize = 4)
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Data with a Linear Trend')
plt.legend()

# %% [markdown]
# 5. Make 500 ***normally*** distributed random numbers and make a histogram of them.

# %%
datarand = np.random.randn(500)
plt.hist(datarand, bins = 9, color = 'm', edgecolor = 'k', alpha = 0.6);
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Normal Distribution')
# Out:
# Text(0.5, 1.0, 'Normal Distribution')

# %% [markdown]
# 6. Make 500 ***uniformly*** distributed random numbers (use `...rand()` instead of `...randn()`) and make a histogram of them.

# %%
datauni = np.random.rand(500)
plt.hist(datauni, bins = 12, color = 'b', edgecolor = 'k', alpha = 0.3) ;
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Uniform Distribution')
# Out:
# Text(0.5, 1.0, 'Uniform Distribution')

# %% [markdown]
# 7. Plot the histograms from 5. and 6. in the same axes to compare the two distributions. Tinker around with the `color = ` and `alpha = ` arguments to `plt.hist()` until you're happy with your figure. Don't forget the axis labels and a legend!

# %%
datauni = np.random.rand(500)
plt.hist(datauni, bins = 9, color = 'b', edgecolor = 'k', alpha = 0.3, label = 'uniform distribution');
datarand = np.random.randn(500)
plt.hist(datarand, bins = 9, color = 'm', edgecolor = 'k', alpha = 0.3, label = 'normal distribution') ;
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Comparison of Distributions')
plt.legend()

# %% [markdown]
# 8. Make a figure with 3 subplots, the first containing the plot of the data with a straight line (from 3.), and the second and third containing each of the 2 histograms created in 5. and 6. Try a 3x1 and  1x3 layout and show your favorite.

# %%
import numpy as np 
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 8))
plt.subplot(3,1,1)
plt.plot(plotx, ploty, 'k-', label = 'linear trend line', linewidth = 1)
plt.plot(a_plotx, a_ploty, 'or', label = 'data', markersize = 4)
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Data with a Linear Trend')
plt.legend()

plt.subplot(3,1,2)
datauni = np.random.rand(500)
plt.hist(datauni, bins = 12, color = '#005f86', edgecolor = 'k', alpha = 0.8) ;
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Uniform Distribution')


plt.subplot(3,1,3)
datarand = np.random.randn(500)
plt.hist(datarand, bins = 9, color = '#bf5700', edgecolor = 'k', alpha = 0.8);
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Normal Distribution')
plt.tight_layout()
